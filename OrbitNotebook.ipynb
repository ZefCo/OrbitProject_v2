# %% [markdown]
# Principle of Lazyness

# %%
import pandas
import pathlib
import re
import numpy as np
# import plotly.graph_objects as go
import datetime
from matplotlib import pyplot as plt

cwd = pathlib.Path.cwd()

# %% [markdown]
# Imports the data

# %%
orbit_table = pandas.read_csv(cwd / "Orbit_Table.csv", header = 0)
orbit_table = orbit_table.set_index("t")
print(orbit_table)
# Out:
#         Earth_x       Earth_y     Sun_x      Sun_y
# t
# 0  1.520000e+11  0.000000e+00     0.000   0.000000
# 1  1.519680e+11  2.530360e+09    96.531   0.892696
# 2  1.518930e+11  5.059650e+09   321.784   4.286010
# 3  1.517750e+11  7.587150e+09   675.747  12.145600
# 4  1.516140e+11  1.011220e+10  1158.360  26.078600
# 5  1.514110e+11  1.263390e+10  1767.810  47.876900

# %% [markdown]
# Plots the graphs

# %%
rows, cols = orbit_table.shape

for c in range(int(cols / 2)):
    cndex = (2*c, 2*c+1)
    col_of_interest: pandas.DataFrame = orbit_table.iloc[:, cndex[0]:cndex[1] + 1].copy()
    # print(col_of_interest.iloc[:, 0])
    name = re.split("_", tuple(col_of_interest.columns)[0])[0]

    plt.plot(col_of_interest.iloc[:, 0], col_of_interest.iloc[:, 1])

plt.show()
